# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\webso\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\webso\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\webso\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\webso\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\webso\anaconda3\lib\site-packages (from requests) (2024.8.30)

# %%
import requests

BASE_URL = "https://veiculos.fipe.org.br/api/veiculos"

headers = {
    "Content-Type": "application/json",
    "Referer": "https://veiculos.fipe.org.br/",
}

def get_tabela_referencia():
    resp = requests.post(f"{BASE_URL}/ConsultarTabelaDeReferencia", headers=headers)
    return resp.json()[0]["Codigo"]

def get_marcas(tipo, tabela):
    payload = {"codigoTabelaReferencia": tabela, "codigoTipoVeiculo": tipo}
    resp = requests.post(f"{BASE_URL}/ConsultarMarcas", headers=headers, json=payload)
    return resp.json()

def get_modelos(tipo, tabela, marca):
    payload = {
        "codigoTabelaReferencia": tabela,
        "codigoTipoVeiculo": tipo,
        "codigoMarca": marca,
    }
    resp = requests.post(f"{BASE_URL}/ConsultarModelos", headers=headers, json=payload)
    return resp.json()["Modelos"]

def get_anos(tipo, tabela, marca, modelo):
    payload = {
        "codigoTabelaReferencia": tabela,
        "codigoTipoVeiculo": tipo,
        "codigoMarca": marca,
        "codigoModelo": modelo,
    }
    resp = requests.post(f"{BASE_URL}/ConsultarAnoModelo", headers=headers, json=payload)
    return resp.json()

def get_valor(tipo, tabela, marca, modelo, ano, codigo_combustivel):
    payload = {
        "codigoTabelaReferencia": tabela,
        "codigoMarca": marca,
        "codigoModelo": modelo,
        "codigoTipoVeiculo": tipo,
        "anoModelo": int(ano),
        "codigoTipoCombustivel": int(codigo_combustivel),
        "tipoConsulta": "tradicional",
        "modeloCodigoExterno": None,
    }
    resp = requests.post(f"{BASE_URL}/ConsultarValorComTodosParametros", headers=headers, json=payload)
    return resp.json()

# %%
# Obter a tabela de referência FIPE
tabela = get_tabela_referencia()
print("Tabela de referência:", tabela)

# Buscar as marcas de carros (tipo 1) e exibir as 10 primeiras
tipo_veiculo = 2  # 2 = Moto
marcas_carros = get_marcas(tipo_veiculo, tabela)

# Exibir as 10 primeiras marcas para escolher
for m in marcas_carros[:100]:
    print(f"{m['Value']} - {m['Label']}")
# Out:
# Tabela de referência: 322
# 60 - ADLY
# 61 - AGRALE
# 131 - AMAZONAS
# 62 - APRILIA
# 63 - ATALA
# 216 - AVELLOZ
# 64 - BAJAJ
# 205 - BEE
# 162 - Benelli
# 65 - BETA
# 66 - BIMOTA
# 67 - BMW
# 68 - BRANDY
# 130 - BRAVA
# 150 - BRP
# 117 - BUELL
# 155 - BUENO
# 212 - BULL
# 69 - byCristo
# 70 - CAGIVA
# 71 - CALOI
# 72 - DAELIM
# 145 - DAFRA
# 137 - DAYANG
# 142 - DAYUN
# 73 - DERBI
# 74 - DUCATI
# 75 - EMME
# 248 - FEVER
# 132 - FOX
# 209 - FUSCO MOTOSEGURA
# 128 - FYM
# 143 - GARINNI
# 76 - GAS GAS
# 133 - GREEN
# 138 - HAOBAO
# 203 - HAOJUE
# 77 - HARLEY-DAVIDSON
# 78 - HARTFORD
# 79 - HERO
# 80 - HONDA
# 81 - HUSABERG
# 82 - HUSQVARNA
# 202 - INDIAN
# 158 - IROS
# 141 - JIAPENG VOLCANO
# 174 - JOHNNYPAG
# 151 - JONNY
# 129 - KAHENA
# 118 - KASINSKI
# 85 - KAWASAKI
# 87 - KTM
# 204 - KYMCO
# 159 - LANDUM
# 88 - L'AQUILA
# 89 - LAVRALE
# 139 - LERIVO
# 178 - LIFAN
# 148 - Lon-V
# 175 - MAGRÃO TRICICLOS
# 146 - Malaguti
# 126 - MIZA
# 90 - MOTO GUZZI
# 201 - MOTOCAR
# 200 - MOTORINO
# 160 - MRX
# 91 - MV AGUSTA
# 92 - MVK
# 239 - NIU
# 93 - ORCA
# 164 - PEGASSI
# 94 - PEUGEOT
# 95 - PIAGGIO
# 210 - POLARIS
# 173 - REGAL RAPTOR
# 198 - RIGUETE
# 192 - Royal Enfield
# 96 - SANYANG
# 134 - SHINERAY
# 97 - SIAMOTO
# 98 - SUNDOWN
# 237 - SUPER SOCO
# 99 - SUZUKI
# 176 - TARGOS
# 187 - TIGER
# 119 - TRAXX
# 100 - TRIUMPH
# 244 - Ventane Motors
# 180 - VENTO
# 215 - VOLTZ
# 243 - WATTS
# 135 - WUYANG
# 101 - YAMAHA
# 242 - ZONTES

# %%
# Código de exemplo: listar os modelos da marca "FIAT" (código 59)
tipo_veiculo  = 2       # 2 = moto
codigo_marca  = 80      # Marca HONDA
tabela        = get_tabela_referencia()

modelos_fiat = get_modelos(tipo_veiculo, tabela, codigo_marca)

# Exibir os 10 primeiros modelos para facilitar a escolha
for m in modelos_fiat[:300]:
    print(f"{m['Value']} – {m['Label']}")
# Out:
# 9265 – ADV 150
# 11305 – ADV 160
# 2763 – AMERICA CLASSIC 1600
# 7467 – BIZ 110i
# 11239 – BIZ 125 ES/ 125 ES FLEX
# 5515 – BIZ 125 EX/ 125 EX FLEX
# 11201 – BIZ 125 KS/ 125 KS FLEX
# 7468 – BIZ 125/125i Flex
# 3963 – BIZ 125+
# 2764 – C 100 BIZ/ 100 BIZ KS
# 2765 – C 100 BIZ+
# 2766 – C 100 BIZ-ES
# 2767 – C 100 DREAM
# 9776 – CB 1000R Black Edition
# 5679 – CB 1000R/ABS
# 11087 – CB 250 TWISTER/FLEXONE
# 10378 – CB 300F Twister Flex
# 4939 – CB 300R/ 300R FLEX
# 2768 – CB 450 DX
# 2769 – CB 500
# 6619 – CB 500F
# 6821 – CB 500X
# 2770 – CB 600F HORNET
# 7058 – CB 650F
# 9030 – CB 650R
# 4412 – CB1300 SUPER FOUR
# 2771 – CBR 1000 F
# 2772 – CBR 1000 RR Fireblade
# 8306 – CBR 1000 RR Fireblade SP
# 9636 – CBR 1000 RR-R Fireblade SP
# 10610 – CBR 1000 RR-R Fireblade SP 30TH EDITION
# 2773 – CBR 1100 XX SUPER BLACKBIRD
# 6041 – CBR 250R
# 2774 – CBR 450
# 2775 – CBR 450 SR
# 6676 – CBR 500R
# 2776 – CBR 600 F
# 2777 – CBR 600 RR
# 9072 – CBR 650 R
# 7059 – CBR 650F
# 2778 – CBR 900 RR FIRE BLADE
# 2779 – CBX 150 AERO
# 2780 – CBX 200 STRADA
# 2781 – CBX 250 TWISTER
# 2782 – CBX 750 FOUR
# 2783 – CBX 750 FOUR INDY
# 2784 – CBX 750 R
# 2785 – CG 125
# 4913 – CG 125 CARGO ES
# 6875 – CG 125 CARGO ESD
# 2786 – CG 125 CARGO/ CARGO KS/125i CARGO
# 2787 – CG 125 FAN / FAN KS / 125 i FAN
# 4842 – CG 125 FAN ES
# 6567 – CG 125 FAN ESD
# 2788 – CG 125 TITAN
# 2789 – CG 125 TITAN-ES
# 2790 – CG 125 TITAN-KS
# 2791 – CG 125 TITAN-KSE
# 2792 – CG 125 TODAY
# 6876 – CG 150 CARGO ESD FLEX
# 5432 – CG 150 FAN ESDi/ 150 FAN ESDi FLEX
# 5095 – CG 150 FAN ESi/ 150 FAN ESi FLEX
# 2793 – CG 150 SPORT
# 7108 – CG 150 START FLEXONE
# 2794 – CG 150 TITAN-ES
# 4914 – CG 150 TITAN-ES MIX
# 4915 – CG 150 TITAN-ESD MIX/FLEX
# 2795 – CG 150 TITAN-ESD/ TITAN SPECIAL EDITION
# 5051 – CG 150 TITAN-EX MIX/FLEX
# 4916 – CG 150 TITAN-KS MIX
# 2796 – CG 150 TITAN-KS/ TITAN-JOB
# 10840 – CG 160 CARGO Flex
# 7329 – CG 160 FAN ESDi FLEXONE
# 8071 – CG 160 FAN Flex
# 7525 – CG 160 START
# 8602 – CG 160 TITAN 25TH ANNIVERSARY
# 7330 – CG 160 TITAN FLEXONE/Ed.Especial 40 Anos
# 8976 – CG 160 TITAN S Flex
# 2797 – CH 125-R SPACY
# 2798 – CR 125
# 2799 – CR 250
# 2800 – CR 80
# 7855 – CRF 1000L AFRICA TWIN
# 8800 – CRF 1000L AFRICA TWIN ADV. SPORTS TE
# 8801 – CRF 1000L AFRICA TWIN ADVENTURE SPORTS
# 7856 – CRF 1000L AFRICA TWIN TE
# 9508 – CRF 1100L AFRICA TWIN
# 9509 – CRF 1100L AFRICA TWIN ADV. SPORTS ES
# 11243 – CRF 1100L AFRICA TWIN ADV. SPORTS ES DCT
# 11244 – CRF 1100L AFRICA TWIN DCT
# 6859 – CRF 110F
# 6195 – CRF 150F
# 4446 – CRF 230 F
# 8540 – CRF 250 F
# 10379 – CRF 250 R
# 11473 – CRF 250 RX
# 4917 – CRF 250 X
# 6455 – CRF 250L
# 9100 – CRF 450 R
# 9101 – CRF 450 RX
# 8705 – CRF 450 X
# 6877 – CTX 700N
# 2801 – DOMINATOR 650
# 8557 – ELITE 125
# 10125 – Forza 350
# 2802 – GOLD WING 1500/ 1800
# 8649 – GOLD WING TOUR 1800
# 4994 – LEAD 110
# 2803 – MAGNA 750
# 6135 – NC 700 X/ 700X ABS
# 7174 – NC 750X/NC 750X ABS
# 11246 – NC 750X/NC 750X ABS DCT
# 2804 – NX 150
# 2805 – NX 200
# 2806 – NX 350 SAHARA
# 6252 – NX 400i FALCON
# 2807 – NX-4 FALCON 400
# 2808 – NXR 125 BROS ES
# 2809 – NXR 125 BROS KS
# 3843 – NXR 150 BROS ES
# 5136 – NXR 150 BROS ES MIX/FLEX
# 2810 – NXR 150 BROS ESD
# 5137 – NXR 150 BROS ESD MIX/FLEX
# 3844 – NXR 150 BROS KS
# 5138 – NXR 150 BROS KS MIX/FLEX
# 7438 – NXR 160 BROS
# 7109 – NXR 160 BROS ESD FLEXONE
# 7110 – NXR 160 BROS ESDD FLEXONE
# 11203 – NXR 160 BROS FLEX
# 8169 – PCX 150 SPORT
# 6473 – PCX 150/DLX
# 10149 – PCX 160
# 10150 – PCX 160 DLX
# 4264 – POP 100 97cc
# 7331 – POP 110i
# 11090 – POP 110i ES
# 10954 – SAHARA 300 ABS FLEX
# 10955 – SAHARA 300 ADVENTURE ABS FLEX
# 10956 – SAHARA 300 RALLY ABS FLEX
# 7932 – SH 150i/DLX
# 7526 – SH 300i
# 8541 – SH 300i Sport
# 2811 – SHADOW 1100 AC
# 2812 – SHADOW 1100 OURO
# 2813 – SHADOW AM 750
# 2814 – SHADOW VT 1100
# 2815 – SUPER HAWK 1000
# 2816 – TRX 350 FOURTRAX  FM QUADRICICLO
# 2817 – TRX 350 FOURTRAX  TM QUADRICICLO
# 4709 – TRX 420 FOURTRAX   TM 4x2 QUADRICICLO
# 4708 – TRX 420 FOURTRAX  FM 4x4 QUADRICICLO
# 2818 – VALKYRIE 1500
# 5562 – VFR 1200F
# 6311 – VFR 1200X CROSSTOURER
# 2819 – VT 600 C SHADOW
# 3918 – VT 750 SHADOW
# 2820 – VTX 1800R/ 1800S/ 1800C 1795cc
# 8307 – X-ADV 745cc
# 4447 – XL 1000V VARADERO
# 2821 – XL 125 DUTY
# 2822 – XL 125 S
# 5546 – XL 700V TRANSALP
# 2823 – XLR 125
# 2824 – XLR 125 ES
# 2825 – XLX 250 R
# 2826 – XLX 350 R
# 2827 – XR 200 R
# 2828 – XR 250 TORNADO
# 11157 – XR 300L TORNADO FLEX
# 2829 – XR 650
# 9031 – XRE 190 ADVENTURE FLEX
# 7607 – XRE 190/ Flex
# 7912 – XRE 300 ADVENTURE FLEX
# 6720 – XRE 300 RALLY FLEX
# 4940 – XRE 300/ 300 ABS/ FLEX

# %%
# Exemplo: listar anos do modelo com código 5940
tipo_veiculo   = 2     # 1 = carro
codigo_marca   = 80    # continua sendo FIAT (ou o código que você usou)
codigo_modelo  = 10378  # substitua pelo código do modelo escolhido
tabela         = get_tabela_referencia()

anos_disponiveis = get_anos(tipo_veiculo, tabela, codigo_marca, codigo_modelo)

# Mostrar os 10 primeiros anos para facilitar
for a in anos_disponiveis[:10]:
    print(f"{a['Value']} – {a['Label']}")
# Out:
# 32000-1 – 32000
# 2025-1 – 2025
# 2024-1 – 2024
# 2023-1 – 2023

# %%
# Exemplo: consultar preço FIPE de FIAT Argo 1.0 FIRE FLEX 2023 (código 2023-1)
tipo_veiculo       = 2         # 2 = Moto
codigo_marca       = 87        # 67 = BMW, 80 = Honda, 100 = Triumph, 101 = Yamaha, 242 = Zontes, 87 = KTM
codigo_modelo      = 7332      # Modelos 6821 = Honda CB500X, 10378 - CB 300F, 4805 - BMW F800 GS, 8535 - BMW F850 GS, 7332 = DUKE 200, 7333 = DUKE 390
ano_modelo_combust = "2015-1"  # substitua pelo valor exato que você anotou
tabela             = get_tabela_referencia()

# Separe em ano e tipo de combustível
ano_modelo   = ano_modelo_combust.split("-")[0]       # ex.: "2023"
cod_combust  = ano_modelo_combust.split("-")[1]       # ex.: "1" para Gasolina

resultado = get_valor(
    tipo_veiculo,
    tabela,
    codigo_marca,
    codigo_modelo,
    ano_modelo,
    cod_combust
)

print("\n--- Resultado FIPE ---")
print(f"Veículo: {resultado['Marca']} {resultado['Modelo']}")
print(f"Ano/Combustível: {resultado['AnoModelo']} / {resultado['Combustivel']}")
print(f"Preço FIPE: {resultado['Valor']}")
# Out:
# --- Resultado FIPE ---
# Veículo: KTM DUKE 200/ABS
# Ano/Combustível: 2015 / Gasolina
# Preço FIPE: R$ 12.588,00
